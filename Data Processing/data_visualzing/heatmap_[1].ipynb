# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("INFO284_exam_data_Reading_only.csv")

# %% [markdown]
# # data

# %%
df
# Out:
#        Message ID      Message time Message date Message clock  \
# 0         1497177        01.01.2018   01/01/2018      00:00:00
# 1         1497178        01.01.2018   01/01/2018      00:00:00
# 2         1497178        01.01.2018   01/01/2018      00:00:00
# 3         1497178        01.01.2018   01/01/2018      00:00:00
# 4         1497178        01.01.2018   01/01/2018      00:00:00
# ...           ...               ...          ...           ...
# 40770     1535560  16.02.2018 20:57   16/02/2018      20:57:00
# 40771     1535561  16.02.2018 20:58   16/02/2018      20:58:00
# 40772     1535561  16.02.2018 20:58   16/02/2018      20:58:00
# 40773     1535561  16.02.2018 20:58   16/02/2018      20:58:00
# 40774     1535561  16.02.2018 20:58   16/02/2018       20:58:0
#
#              Start time  Start date Start time clock  Start position latitude  \
# 0            31.12.2017  31/12/2017         00:00:00                  -6035.0
# ...

# %%
df.dtypes
# Out:
# Message ID                      int64
# Message time                   object
# Message date                   object
# Message clock                  object
# Start time                     object
# Start date                     object
# Start time clock               object
# Start position latitude       float64
# Start position longitude      float64
# Main area start (code)        float64
# Main area start                object
# Location start (code)         float64
# Sea depth, start              float64
# Stop time                      object
# Stop date                      object
# Stop time clock                object
# Duration                      float64
# Catch year                    float64
# Stop position latitude        float64
# Stop position longitude       float64
# Main Area stop (code)         float64
# Main area stop                 object
# Location stop (code)          float64
# Sea depth, stop               float64
# Drag distance                 float64
# ...

# %%
df.describe()
# Out:
#          Message ID  Start position latitude  Start position longitude  \
# count  1.758090e+05            175809.000000             175809.000000
# mean   1.594451e+06             56360.673617              11756.102321
# std    6.305766e+04             23871.113082              12305.012347
# min    1.497177e+06            -73827.000000            -179517.000000
# 25%    1.538049e+06             58367.000000               2781.000000
# 50%    1.589271e+06             64417.000000               9013.000000
# 75%    1.657713e+06             71117.000000              18917.000000
# max    1.692364e+06             89983.000000             179617.000000
#
#        Main area start (code)  Location start (code)  Sea depth, start  \
# count           174766.000000          174766.000000     175809.000000
# mean                12.968375              19.651105       -239.119215
# std                 12.737155              18.772792        233.533850
# ...

# %%
from collections import Counter

# Assuming 'my_list' is your list with a large number of elements
my_list = df["Gear FDIR"] # Example list

# Count occurrences of each element in the list
element_counts = Counter(my_list)

# Display the counts
for element, count in element_counts.items():
    print(f"{element}: {count} times")

# %% [markdown]
# # relationship between species and gear

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
sns.countplot(x='Species FAO (code)', hue='Gear FAO (code)', data=df)
plt.xticks(rotation=100)
plt.title('Count of Fish Species by Fish Equipment')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %%
# Stacked Bar Plot
fish_equipment_counts = df.groupby(['Gear FAO (code)', 'Species FAO (code)']).size().unstack(fill_value=0)
fish_equipment_counts.plot(kind='bar', stacked=True, figsize=(10, 6))
plt.xticks(rotation=45)
plt.title('Distribution of Fish Species by Fish Equipment')
plt.xlabel('Fish Equipment')
plt.ylabel('Count')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %%
# Heatmap
plt.figure(figsize=(30,40))
heatmap_data = df.groupby(['Species FAO (code)', 'Gear FAO (code)']).size().unstack(fill_value=0)
sns.heatmap(heatmap_data, cmap='Reds', annot=True, fmt='d', square = True)
plt.title('Heatmap of Fish Species and Fish Equipment')
plt.show()

# %% [markdown]
# # relationship between species and boat length

# %%
# Stacked Bar Plot
fish_equipment_counts = df.groupby(['Length group', 'Species FAO (code)']).size().unstack(fill_value=0)
fish_equipment_counts.plot(kind='bar', stacked=True, figsize=(10, 6))
plt.xticks(rotation=45)
plt.title('Distribution of Fish Species by boat length')
plt.xlabel('boat length')
plt.ylabel('Count')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %%
# Heatmap
plt.figure(figsize=(30, 10))
heatmap_data = df.groupby(['Length group','Species FAO (code)']).size().unstack(fill_value=0)
sns.heatmap(heatmap_data, cmap='Reds', annot=True, fmt='d', square = True)
plt.title('Heatmap of Fish Species and boat length')
plt.show()

# %% [markdown]
# # useless

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Scatter plot
plt.figure(figsize=(12, 8))
sns.scatterplot(y= 'Species FAO (code)', x='Drag distance', data=df)
plt.xlabel('drag distance')
plt.ylabel('Fish Species')
plt.title('Relationship between drag distance and Fish Species')
plt.grid(True)
plt.show()
