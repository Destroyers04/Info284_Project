# %%
import pandas as pd

columns_of_interest = ["Hovedart FAO (kode)", "Hovedart FAO (kode)", "Hovedart FAO", 
                       "Hovedart - FDIR (kode)", "Art FAO (kode)", "Art FAO", "Art - FDIR (kode)", 
                       "Art - FDIR", "Art - gruppe (kode)", "Art - gruppe"] 

# Have no ide why, but unnless I use the complete pathing for csv file I cant make it work, even when the "short" or reletiv path shoud be enouf.
df = pd.read_csv(r"C:\Users\Sverre\Documents\VS Studio. filer\INFO284\Obli\Info284_Project\Data Processing\data_visualzing\fish-data.csv", sep=";", usecols=columns_of_interest)
pd.set_option('display.max_rows', None)

# This displays all the different types of entries for each of the columms above, and the number of times mentioned
for column in df.columns:
    print(f"Column: {column}")
    print(df[column].value_counts())
    print()
# Out:
# Column: Hovedart FAO (kode)
# Hovedart FAO (kode)
# COD    86215
# POK    66311
# PRA    36977
# HAD    28176
# LIN    13387
# NOP     7796
# USK     7168
# HER     6846
# WHB     6166
# CRQ     6070
# REB     6065
# HKE     5964
# GHL     4986
# MON     2552
# SAN     2064
# CAP     1378
# HOM     1224
# MAC     1146
# ARU     1120
# CAS      896
# REG      785
# POL      780
# LAH      683
# PLE      615
# KRI      552
# SPR      541
# CRE      532
# ARY      314
# ARG      298
# MIW      296
# WHG      294
# PAN      221
# JCM      207
# PAL      205
# CAA      203
# CUS      196
# CAB      163
# DGS      138
# SRX      129
# CAT      112
# MZZ      108
# NEP       96
# HAL       95
# GDG       70
# WIT       38
# BLI       37
# TOA       34
# LEM       28
# GFB       27
# KCD       22
# SQE       21
# CMO       18
# GAD       12
# MEG       10
# PLA        9
# MAV        9
# FLE        8
# LUM        8
# LXX        8
# HKX        8
# PLZ        4
# SOS        3
# BHG        3
# ...
